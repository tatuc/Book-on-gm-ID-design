# %%
import pandas as pd
import numpy as np
from numpy.core.records import fromarrays
from scipy.io import savemat

# %%
choice = 1  #start from 0
devices = ['sg13_lv_nmos', 'sg13_lv_pmos', 'sg13_hv_nmos', 'sg13_hv_pmos']

# widths used for characterization
w = np.array([5, 5, 5, 5])
nfing = np.array([1, 1, 1, 1])

# %%
# read ngspice data
df_raw = pd.read_csv('./simulation/techsweep_'+devices[choice]+'.txt', sep='\s+')
par_names = df_raw.columns.to_list()
fet_name = par_names[1].split('[')[0]

# remove unwanted columns and rename for readability
df = df_raw.drop(['g', 'g.1', 'b', 'd', 'n'], axis=1)
df = df.apply(pd.to_numeric)
df.columns = df.columns.str.replace(fet_name, '')
df.columns = df.columns.str.replace(fet_name[1:], '')
df.columns = df.columns.str.replace('[dc]', '')
df.columns = df.columns.str.replace('onoise..', 'n')
df.columns = df.columns.str.removeprefix('@')
df.columns = df.columns.str.removeprefix('[')
df.columns = df.columns.str.removesuffix(']')
df
# Out:
#                  cdd           cgb           cgd         cgdol           cgg  \
# 0       1.879000e-20  5.996000e-16  2.399000e-19  2.422000e-15  6.001000e-16
# 1       6.432000e-21  5.501000e-16  1.359000e-19  2.422000e-15  5.503000e-16
# 2       2.443000e-21  5.125000e-16  8.599000e-20  2.422000e-15  5.127000e-16
# 3       8.014000e-21  5.996000e-16 -4.961000e-18  2.412000e-15  6.000000e-16
# 4       2.739000e-21  5.501000e-16 -5.059000e-18  2.412000e-15  5.503000e-16
# ...              ...           ...           ...           ...           ...
# 129649  3.089000e-16  9.862000e-15  3.561000e-16  2.431000e-15  1.298000e-13
# 129650  2.678000e-16  9.649000e-15  3.107000e-16  2.431000e-15  1.294000e-13
# 129651  3.252000e-16  1.010000e-14  3.718000e-16  2.422000e-15  1.303000e-13
# 129652  2.809000e-16  9.868000e-15  3.238000e-16  2.422000e-15  1.298000e-13
# 129653  2.450000e-16  9.654000e-15  2.842000e-16  2.422000e-15  1.294000e-13
#
#                  cgs         cgsol           cjd           cjs           css  \
# 0       2.399000e-19  2.422000e-15  1.834000e-15  1.834000e-15  1.879000e-20
# 1       1.359000e-19  2.422000e-15  1.682000e-15  1.682000e-15  6.432000e-21
# 2       8.599000e-20  2.422000e-15  1.571000e-15  1.571000e-15  2.443000e-21
# 3       5.381000e-18  2.422000e-15  1.812000e-15  1.834000e-15  1.925000e-20
# 4       5.288000e-18  2.422000e-15  1.666000e-15  1.682000e-15  6.601000e-21
# ...              ...           ...           ...           ...           ...
# 129649  1.196000e-13  2.659000e-15  1.264000e-15  1.682000e-15  8.068000e-14
# 129650  1.194000e-13  2.659000e-15  1.225000e-15  1.571000e-15  8.001000e-14
# 129651  1.198000e-13  2.659000e-15  1.303000e-15  1.834000e-15  8.149000e-14
# 129652  1.196000e-13  2.659000e-15  1.259000e-15  1.682000e-15  8.067000e-14
# 129653  1.194000e-13  2.659000e-15  1.220000e-15  1.571000e-15  8.001000e-14
#
#         ...            gm           gmb           ids             l  \
# 0       ... -1.830000e-12  0.000000e+00  0.000000e+00  1.300000e-07
# 1       ... -1.830000e-12  0.000000e+00  0.000000e+00  1.300000e-07
# 2       ... -1.830000e-12 -3.988000e-34  0.000000e+00  1.300000e-07
# 3       ...  8.468000e-10  1.836000e-10  3.257000e-11  1.300000e-07
# 4       ...  2.982000e-10  5.657000e-11  1.126000e-11  1.300000e-07
# ...     ...           ...           ...           ...           ...
# 129649  ...  9.222000e-05  1.992000e-05  4.171000e-05  3.000000e-06
# 129650  ...  8.818000e-05  1.747000e-05  3.798000e-05  3.000000e-06
# 129651  ...  9.652000e-05  2.302000e-05  4.601000e-05  3.000000e-06
# 129652  ...  9.228000e-05  1.993000e-05  4.173000e-05  3.000000e-06
# 129653  ...  8.823000e-05  1.748000e-05  3.800000e-05  3.000000e-06
#
#                  sfl           sid     vth   vb     vd   vg
# 0       0.000000e+00  5.780000e-29  0.4281  0.0  0.000  0.0
# 1       0.000000e+00  1.994000e-29  0.4575 -0.2  0.000  0.0
# 2       0.000000e+00  7.633000e-30  0.4852 -0.4  0.000  0.0
# 3       7.319000e-28  4.282000e-29  0.4280  0.0  0.025  0.0
# 4       9.211000e-29  1.480000e-29  0.4574 -0.2  0.025  0.0
# ...              ...           ...     ...  ...    ...  ...
# 129649  1.978000e-18  2.523000e-24  0.3814 -0.2  1.175  1.2
# 129650  1.668000e-18  2.366000e-24  0.4111 -0.4  1.175  1.2
# 129651  2.367000e-18  2.702000e-24  0.3493  0.0  1.200  1.2
# 129652  1.979000e-18  2.524000e-24  0.3814 -0.2  1.200  1.2
# 129653  1.669000e-18  2.367000e-24  0.4111 -0.4  1.200  1.2
#
# [129654 rows x 21 columns]

# %%
# sweep variable vectors
l =   np.unique(df['l'])
vgs = np.unique(df['vg'])
vds = np.unique(df['vd'])
vsb = np.unique(-df['vb'])

# %%
# ngspice sweep order is l, vgs, vds, vsb
dims = [len(l), len(vgs), len(vds), len(vsb)]
id = np.reshape(df['ids'].values, dims)
vt = np.reshape(df['vth'].values, dims)
gm = np.reshape(df['gm'].values, dims)
gmb = np.reshape(df['gmb'].values, dims)
gds = np.reshape(df['gds'].values, dims)
cgg = np.reshape(df['cgg'].values, dims) \
      + np.reshape(df['cgdol'].values, dims) \
      + np.reshape(df['cgsol'].values, dims)
cgb = -np.reshape(df['cgb'].values, dims)
cgd = np.reshape(df['cgd'].values, dims) \
      + np.reshape(df['cgdol'].values, dims)
cgs = np.reshape(df['cgs'].values, dims) \
      + np.reshape(df['cgsol'].values, dims)
cdd = np.reshape(df['cdd'].values, dims) \
      + np.reshape(df['cjd'].values, dims) \
      + np.reshape(df['cgdol'].values, dims)
css = np.reshape(df['css'].values, dims) \
      + np.reshape(df['cjs'].values, dims) \
      + np.reshape(df['cgsol'].values, dims)
sth = np.reshape(df['sid'].values, dims)
sfl = np.reshape(df['sfl'].values, dims)

# %%
dic = {
  "INFO": "IHP, 130nm BiCMOS, PSP",
  "CORNER": "NOM",
  "TEMP": 300.0,
  "VGS": vgs,
  "VDS": vds,
  "VSB": vsb,
  "L": l,
  "W": w[choice],
  "NFING": nfing[choice],
  "ID": id,
  "VT": vt,
  "GM": gm,
  "GMB": gmb,
  "GDS": gds,
  "CGG": cgg,
  "CGB": cgb,
  "CGD": cgd,
  "CGS": cgs,
  "CDD": cdd,
  "CSS": css,
  "STH": sth,
  "SFL": sfl
}
savemat('./simulation/'+devices[choice]+'.mat', {devices[choice]: dic})
